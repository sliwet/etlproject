# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine

# %%
# default user: postgres
# password: postgres
# databasename: etlproject
engine = create_engine('postgresql://postgres:postgres@localhost:5432/etlproject')
connection = engine.connect()

# %%
stores = pd.read_sql_query('SELECT * FROM stores',connection)
storetypes = stores['stype'].unique()
print(f"Number of store types: {len(storetypes)}")
stores.head()
# Out:
# Number of store types: 3
#    sn stype   ssize
# 0   1     A  151315
# 1   2     A  202307
# 2   3     B   37392
# 3   4     A  205863
# 4   5     B   34875

# %%
train = pd.read_sql_query('SELECT * FROM train',connection)
train.head()
# Out:
#    sn  dept       wdate    wsales  isholiday
# 0   1     1  2010-02-05  24924.50      False
# 1   1     1  2010-02-12  46039.49       True
# 2   1     1  2010-02-19  41595.55      False
# 3   1     1  2010-02-26  19403.54      False
# 4   1     1  2010-03-05  21827.90      False

# %%
features = pd.read_sql_query('SELECT * FROM features',connection)
features.head()
# Out:
#    sn       wdate  tempr   fuel  md1  md2  md3  md4  md5         cpi    uir  \
# 0   1  2010-02-05  42.31  2.572  NaN  NaN  NaN  NaN  NaN  211.096358  8.106
# 1   1  2010-02-12  38.51  2.548  NaN  NaN  NaN  NaN  NaN  211.242170  8.106
# 2   1  2010-02-19  39.93  2.514  NaN  NaN  NaN  NaN  NaN  211.289143  8.106
# 3   1  2010-02-26  46.63  2.561  NaN  NaN  NaN  NaN  NaN  211.319643  8.106
# 4   1  2010-03-05  46.50  2.625  NaN  NaN  NaN  NaN  NaN  211.350143  8.106
#
#    isholiday
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False

# %%
len(train)
# Out:
# 421570

# %%
selectedstore = 1
selecteddept = 1
holsales = train.loc[(train["sn"] == selectedstore) & (train["dept"] == selecteddept)& (train["isholiday"] == True), :]
normalsales = train.loc[(train["sn"] == selectedstore) & (train["dept"] == selecteddept)& (train["isholiday"] == False), :]

# %%
holsales.head()
# Out:
#     sn  dept       wdate    wsales  isholiday
# 1    1     1  2010-02-12  46039.49       True
# 31   1     1  2010-09-10  18194.74       True
# 42   1     1  2010-11-26  18820.29       True
# 47   1     1  2010-12-31  19124.58       True
# 53   1     1  2011-02-11  37887.17       True

# %%
# for i in range(len(selected_drugs)):
#     yy = mousecount_reformatted[selected_drugs[i]].tolist()
#     survivalrate = [(100 * y / yy[0]) for y in yy]
xx = holsales['wdate']
yy = holsales['wsales']
xx2 = normalsales['wdate']
yy2 = normalsales['wsales']

plt.plot(xx,yy,'ro:',label = 'Store 1 Department 1')
plt.plot(xx2,yy2,'b^:',label = 'Store 1 Department 1')

plt.title("Survival During Treatment")
plt.xlabel("Time (Days)")
plt.ylabel("Survival Rate (%)")

plt.grid()
plt.legend(loc="lower left")

plt.savefig("survival.png")
plt.show()

# %%
sn1Hol
# Out:
#        sn  dept       wdate    wsales  isholiday
# 1       1     1  2010-02-12  46039.49       True
# 31      1     1  2010-09-10  18194.74       True
# 42      1     1  2010-11-26  18820.29       True
# 47      1     1  2010-12-31  19124.58       True
# 53      1     1  2011-02-11  37887.17       True
# 83      1     1  2011-09-09  17746.68       True
# 94      1     1  2011-11-25  20911.25       True
# 99      1     1  2011-12-30  23350.88       True
# 105     1     1  2012-02-10  36988.49       True
# 135     1     1  2012-09-07  18322.37       True
# 144     1     2  2010-02-12  44682.74       True
# 174     1     2  2010-09-10  45182.50       True
# 185     1     2  2010-11-26  45681.98       True
# 190     1     2  2010-12-31  35819.83       True
# 196     1     2  2011-02-11  47595.35       True
# 226     1     2  2011-09-09  43315.85       True
# 237     1     2  2011-11-25  44259.59       True
# 242     1     2  2011-12-30  43539.94       True
# 248     1     2  2012-02-10  50581.06       True
# 278     1     2  2012-09-07  47344.50       True
# 287     1     3  2010-02-12  10887.84       True
# 317     1     3  2010-09-10  12134.69       True
# 328     1     3  2010-11-26  10706.81       True
# 333     1     3  2010-12-31   8266.14       True
# 339     1     3  2011-02-11  11428.25       True
# 369     1     3  2011-09-09  12778.28       True
# 380     1     3  2011-11-25   9317.56       True
# 385     1     3  2011-12-30   8848.44       True
# 391     1     3  2012-02-10  12388.85       True
# 421     1     3  2012-09-07  18368.51       True
# ...    ..   ...         ...       ...        ...
# 9861    1    96  2011-09-09  32182.39       True
# 9872    1    96  2011-11-25  45408.45       True
# 9877    1    96  2011-12-30  35210.98       True
# 9883    1    96  2012-02-10  31967.59       True
# 9913    1    96  2012-09-07  39935.58       True
# 9922    1    97  2010-02-12  33874.47       True
# 9952    1    97  2010-09-10  38996.39       True
# 9963    1    97  2010-11-26  28754.58       True
# 9968    1    97  2010-12-31  28591.28       True
# 9974    1    97  2011-02-11  36562.46       True
# 10004   1    97  2011-09-09  39703.09       True
# 10015   1    97  2011-11-25  30320.41       True
# 10020   1    97  2011-12-30  29166.73       True
# 10026   1    97  2012-02-10  36981.11       True
# 10056   1    97  2012-09-07  43039.76       True
# 10065   1    98  2010-02-12  16309.73       True
# 10095   1    98  2010-09-10  11125.38       True
# 10106   1    98  2010-11-26  17693.74       True
# 10111   1    98  2010-12-31   8705.87       True
# 10117   1    98  2011-02-11  16060.11       True
# 10147   1    98  2011-09-09  11580.27       True
# 10158   1    98  2011-11-25  19452.26       True
# 10163   1    98  2011-12-30  10806.26       True
# 10169   1    98  2012-02-10  16837.30       True
# 10199   1    98  2012-09-07  11544.63       True
# 10216   1    99  2011-09-09     40.00       True
# 10217   1    99  2011-11-25   2400.00       True
# 10221   1    99  2011-12-30    400.00       True
# 10223   1    99  2012-02-10   1070.00       True
# 10240   1    99  2012-09-07      0.05       True
#
# [723 rows x 5 columns]
